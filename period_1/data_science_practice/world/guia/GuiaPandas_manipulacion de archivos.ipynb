# %% [markdown]
# #  Guia de manejo de archivos en Pandas

# %% [markdown]
# Para el uso de esta guia se utilizan tres archivos adjuntos: "Churn.cvs", "Churn2.xlsx" y "example.json"

# %%
import pandas as pd

# %% [markdown]
# 1. Leer un archivo CSV

# %%
tabla = pd.read_csv('Churn.csv')
tabla
# Out:
#        No.  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0        1  7590-VHVEG  Female              0     Yes         No     1.0
# 1        2  5575-GNVDE    Male              0      No         No    34.0
# 2        3  3668-QPYBK    Male              0      No         No     2.0
# 3        4  7795-CFOCW    Male              0      No         No    45.0
# 4        5  9237-HQITU  Female              0      No         No     2.0
# ...    ...         ...     ...            ...     ...        ...     ...
# 7038  7039  6840-RESVB    Male              0     Yes        Yes    24.0
# 7039  7040  2234-XADUH  Female              0     Yes        Yes    72.0
# 7040  7041  4801-JZAZL  Female              0     Yes        Yes    11.0
# 7041  7042  8361-LTMKD    Male              1     Yes         No     4.0
# 7042  7043  3186-AJIEK    Male              0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# 0              No  No phone service             DSL  ...               No
# 1             Yes                No             DSL  ...              Yes
# 2             Yes                No             DSL  ...               No
# 3              No  No phone service             DSL  ...              Yes
# 4             Yes               NaN             NaN  ...               No
# ...           ...               ...             ...  ...              ...
# 7038          Yes               Yes             DSL  ...              Yes
# 7039          Yes               Yes     Fiber optic  ...              Yes
# 7040           No  No phone service             DSL  ...               No
# 7041          Yes               Yes     Fiber optic  ...               No
# 7042          Yes                No     Fiber optic  ...              Yes
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No          No              No  Month-to-month              Yes
# 1             No          No              No        One year               No
# 2             No          No              No  Month-to-month              Yes
# 3            Yes          No              No        One year               No
# 4             No          No              No  Month-to-month              Yes
# ...          ...         ...             ...             ...              ...
# 7038         Yes         Yes             Yes        One year              Yes
# 7039          No         Yes             Yes        One year              Yes
# 7040          No          No              No  Month-to-month              Yes
# 7041          No          No              No  Month-to-month              Yes
# 7042         Yes         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn
# 0              Electronic check          29.85        39.65     No
# 1                  Mailed check          56.95      2339.30     No
# 2                  Mailed check          53.85        97.00    Yes
# 3     Bank transfer (automatic)          42.30      1596.60     No
# 4              Electronic check          70.70       181.65    Yes
# ...                         ...            ...          ...    ...
# 7038               Mailed check          84.80      1712.70     No
# 7039    Credit card (automatic)         103.20      1723.95     No
# 7040           Electronic check          29.60       697.25     No
# 7041               Mailed check          74.40       116.95    Yes
# 7042  Bank transfer (automatic)         105.65      1357.10     No
#
# [7043 rows x 22 columns]

# %% [markdown]
# 2. Leer un archivo de Excel

# %%
tabla = pd.read_excel('Churn2.xlsx')
tabla
# Out:
#     Unnamed: 0                                         Unnamed: 1
# 0          NaN                                       Introducción
# 1          NaN  La deserción, el abandono, el desgaste, la can...
# 2          NaN                                                NaN
# 3          NaN                                        Diccionario
# 4          NaN                            customerID: Customer ID
# 5          NaN                           gender: Customer gender
# 6          NaN  SeniorCitizen: Whether the customer is a senio...
# 7          NaN  Partner: Whether the customer has a partner or...
# 8          NaN  Dependents: Whether the customer has dependent...
# 9          NaN  tenure: Number of months the customer has stay...
# 10         NaN  PhoneService: Whether the customer has a phone...
# 11         NaN  MultipleLines: Whether the customer has multip...
# 12         NaN  InternetService: Customer’s internet service p...
# 13         NaN  OnlineSecurity: Whether the customer has onlin...
# 14         NaN  OnlineBackup: Whether the customer has online ...
# 15         NaN  DeviceProtection: Whether the customer has dev...
# 16         NaN  TechSupport: Whether the customer has tech sup...
# 17         NaN  StreamingTV: Whether the customer has streamin...
# 18         NaN  StreamingMovies: Whether the customer has stre...
# 19         NaN       Contract: The contract term of the customer
# 20         NaN  PaperlessBilling: Whether the customer has pap...
# 21         NaN      PaymentMethod: The customer’s payment method
# 22         NaN  MonthlyCharges: The amount charged to the cust...
# 23         NaN  TotalCharges: The total amount charged to the ...
# 24         NaN        Churn: Whether the customer churned or not

# %% [markdown]
# 3. Leer una pagina en especial del un archivo Excel

# %%
tabla = pd.read_excel('Churn2.xlsx','Churn') #el segundo parametro es el nombre de la pagina
tabla
# Out:
#        No.  customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0        1  7590-VHVEG  Female              0     Yes         No     1.0
# 1        2  5575-GNVDE    Male              0      No         No    34.0
# 2        3  3668-QPYBK    Male              0      No         No     2.0
# 3        4  7795-CFOCW    Male              0      No         No    45.0
# 4        5  9237-HQITU  Female              0      No         No     2.0
# ...    ...         ...     ...            ...     ...        ...     ...
# 7038  7039  6840-RESVB    Male              0     Yes        Yes    24.0
# 7039  7040  2234-XADUH  Female              0     Yes        Yes    72.0
# 7040  7041  4801-JZAZL  Female              0     Yes        Yes    11.0
# 7041  7042  8361-LTMKD    Male              1     Yes         No     4.0
# 7042  7043  3186-AJIEK    Male              0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService  ... DeviceProtection  \
# 0              No  No phone service             DSL  ...               No
# 1             Yes                No             DSL  ...              Yes
# 2             Yes                No             DSL  ...               No
# 3              No  No phone service             DSL  ...              Yes
# 4             Yes               NaN             NaN  ...               No
# ...           ...               ...             ...  ...              ...
# 7038          Yes               Yes             DSL  ...              Yes
# 7039          Yes               Yes     Fiber optic  ...              Yes
# 7040           No  No phone service             DSL  ...               No
# 7041          Yes               Yes     Fiber optic  ...               No
# 7042          Yes                No     Fiber optic  ...              Yes
#
#      TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No          No              No  Month-to-month              Yes
# 1             No          No              No        One year               No
# 2             No          No              No  Month-to-month              Yes
# 3            Yes          No              No        One year               No
# 4             No          No              No  Month-to-month              Yes
# ...          ...         ...             ...             ...              ...
# 7038         Yes         Yes             Yes        One year              Yes
# 7039          No         Yes             Yes        One year              Yes
# 7040          No          No              No  Month-to-month              Yes
# 7041          No          No              No  Month-to-month              Yes
# 7042         Yes         Yes             Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges TotalCharges  Churn
# 0              Electronic check          29.85        39.65     No
# 1                  Mailed check          56.95      2339.30     No
# 2                  Mailed check          53.85        97.00    Yes
# 3     Bank transfer (automatic)          42.30      1596.60     No
# 4              Electronic check          70.70       181.65    Yes
# ...                         ...            ...          ...    ...
# 7038               Mailed check          84.80      1712.70     No
# 7039    Credit card (automatic)         103.20      1723.95     No
# 7040           Electronic check          29.60       697.25     No
# 7041               Mailed check          74.40       116.95    Yes
# 7042  Bank transfer (automatic)         105.65      1357.10     No
#
# [7043 rows x 22 columns]

# %% [markdown]
# 4. Descartar el indizado del archivo Excel

# %%
tabla = pd.read_excel('Churn2.xlsx','Churn',index_col=0)
tabla
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# No.
# 1     7590-VHVEG  Female              0     Yes         No     1.0
# 2     5575-GNVDE    Male              0      No         No    34.0
# 3     3668-QPYBK    Male              0      No         No     2.0
# 4     7795-CFOCW    Male              0      No         No    45.0
# 5     9237-HQITU  Female              0      No         No     2.0
# ...          ...     ...            ...     ...        ...     ...
# 7039  6840-RESVB    Male              0     Yes        Yes    24.0
# 7040  2234-XADUH  Female              0     Yes        Yes    72.0
# 7041  4801-JZAZL  Female              0     Yes        Yes    11.0
# 7042  8361-LTMKD    Male              1     Yes         No     4.0
# 7043  3186-AJIEK    Male              0      No         No    66.0
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# No.                                                                 ...
# 1              No  No phone service             DSL             No  ...
# 2             Yes                No             DSL            Yes  ...
# 3             Yes                No             DSL            Yes  ...
# 4              No  No phone service             DSL            Yes  ...
# 5             Yes               NaN             NaN             No  ...
# ...           ...               ...             ...            ...  ...
# 7039          Yes               Yes             DSL            Yes  ...
# 7040          Yes               Yes     Fiber optic             No  ...
# 7041           No  No phone service             DSL            Yes  ...
# 7042          Yes               Yes     Fiber optic             No  ...
# 7043          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# No.
# 1                  No          No          No              No  Month-to-month
# 2                 Yes          No          No              No        One year
# 3                  No          No          No              No  Month-to-month
# 4                 Yes         Yes          No              No        One year
# 5                  No          No          No              No  Month-to-month
# ...               ...         ...         ...             ...             ...
# 7039              Yes         Yes         Yes             Yes        One year
# 7040              Yes          No         Yes             Yes        One year
# 7041               No          No          No              No  Month-to-month
# 7042               No          No          No              No  Month-to-month
# 7043              Yes         Yes         Yes             Yes        Two year
#
#      PaperlessBilling              PaymentMethod MonthlyCharges  TotalCharges  \
# No.
# 1                 Yes           Electronic check          29.85         39.65
# 2                  No               Mailed check          56.95       2339.30
# 3                 Yes               Mailed check          53.85         97.00
# 4                  No  Bank transfer (automatic)          42.30       1596.60
# 5                 Yes           Electronic check          70.70        181.65
# ...               ...                        ...            ...           ...
# 7039              Yes               Mailed check          84.80       1712.70
# 7040              Yes    Credit card (automatic)         103.20       1723.95
# 7041              Yes           Electronic check          29.60        697.25
# 7042              Yes               Mailed check          74.40        116.95
# 7043              Yes  Bank transfer (automatic)         105.65       1357.10
#
#       Churn
# No.
# 1        No
# 2        No
# 3       Yes
# 4        No
# 5       Yes
# ...     ...
# 7039     No
# 7040     No
# 7041     No
# 7042    Yes
# 7043     No
#
# [7043 rows x 21 columns]

# %% [markdown]
# 5. Usar solo ciertas columnas del Excel en un rango

# %%
tabla = pd.read_excel('Churn2.xlsx','Churn',index_col=0, usecols="B:F")#solo se mostraran las columnas de la B a la F en la pagina Churn
tabla
# Out:
#             gender  SeniorCitizen Partner Dependents
# customerID
# 7590-VHVEG  Female              0     Yes         No
# 5575-GNVDE    Male              0      No         No
# 3668-QPYBK    Male              0      No         No
# 7795-CFOCW    Male              0      No         No
# 9237-HQITU  Female              0      No         No
# ...            ...            ...     ...        ...
# 6840-RESVB    Male              0     Yes        Yes
# 2234-XADUH  Female              0     Yes        Yes
# 4801-JZAZL  Female              0     Yes        Yes
# 8361-LTMKD    Male              1     Yes         No
# 3186-AJIEK    Male              0      No         No
#
# [7043 rows x 4 columns]

# %% [markdown]
# 6. Usar solo ciertas columnas del Excel por su nombre

# %%
tabla = pd.read_excel('Churn2.xlsx', 'Churn', index_col=0, usecols=["customerID", "tenure", "Churn"])
tabla
# Out:
#             tenure Churn
# customerID
# 7590-VHVEG     1.0    No
# 5575-GNVDE    34.0    No
# 3668-QPYBK     2.0   Yes
# 7795-CFOCW    45.0    No
# 9237-HQITU     2.0   Yes
# ...            ...   ...
# 6840-RESVB    24.0    No
# 2234-XADUH    72.0    No
# 4801-JZAZL    11.0    No
# 8361-LTMKD     4.0   Yes
# 3186-AJIEK    66.0    No
#
# [7043 rows x 2 columns]

# %% [markdown]
# 7. Leer un documento JSON

# %%
tabla = pd.read_json('example.json')
tabla
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %% [markdown]
# 8. Hacer un conteo de valores

# %%
tabla.value_counts()
# Out:
# Duration  Pulse  Maxpulse  Calories
# 45        90     112       180.1       2
# 60        111    151       368.5       2
#           109    153       387.6       2
#           102    127       300.5       2
#           100    120       300.0       2
#                                       ..
# 180       101    127       600.1       1
# 210       108    160       1376.0      1
#           137    184       1860.4      1
# 270       100    131       1729.0      1
# 300       108    143       1500.2      1
# Name: count, Length: 158, dtype: int64

# %% [markdown]
# 9. Detectar valores unicos en la tabla e indicarlos por columnas

# %%
tabla.nunique()
# Out:
# Duration     16
# Pulse        47
# Maxpulse     57
# Calories    145
# dtype: int64

# %% [markdown]
# 10. Suma de todos los valores unicos de una tabla

# %%
tabla.nunique().sum()
# Out:
# np.int64(265)

# %% [markdown]
# 11. Calcular la media por cada columna

# %%
tabla.mean(axis="index")
# Out:
# Duration     63.846154
# Pulse       107.461538
# Maxpulse    134.047337
# Calories    375.800000
# dtype: float64

# %% [markdown]
# 12. Calcular la media por cada fila

# %%
tabla.mean(axis="columns")
# Out:
# 0      177.275
# 1      200.250
# 2      159.500
# 3      152.850
# 4      179.000
#         ...
# 164    148.950
# 165    153.850
# 166    157.550
# 167    166.350
# 168    170.100
# Length: 169, dtype: float64

# %% [markdown]
# 13. Calcular la media de alguna columna en particular

# %%
tabla['Pulse'].mean()
# Out:
# np.float64(107.46153846153847)

# %% [markdown]
# 14. Detectar el valor minimo de una columna

# %%
tabla['Pulse'].min()
# Out:
# np.int64(80)

# %% [markdown]
# 15. Detectar el valor maximo de una columna

# %%
tabla['Pulse'].max()
# Out:
# np.int64(159)

# %% [markdown]
# 16. Detectar los minimos y maximos de toda la tabla

# %%
print("Minimos:")
print(tabla.min())
print("Maximos:")
print(tabla.max())
# Out:
# Minimos:
# Duration     15.0
# Pulse        80.0
# Maxpulse    100.0
# Calories     50.3
# dtype: float64
# Maximos:
# Duration     300.0
# Pulse        159.0
# Maxpulse     184.0
# Calories    1860.4
# dtype: float64

# %% [markdown]
# 17. Detectar valores condicionados. Por ejemplo: Todos las calorias menores a 1000

# %%
tabla.loc[tabla['Calories']<1000]
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.4
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [157 rows x 4 columns]
