# %% [markdown]
# # Clustering
# ### Machine Learning - Hector G. Ceballos (ceballos@tec.mx)

# %%
import numpy as np
import pandas as pd

# %%
# Load data
df = pd.read_csv(r"C:\Users\dilan\Documents\Github\DataAnalysis_and_AI\period_2\Resources\Datasets\procesado.csv")
df
# Out:
#       Unnamed: 0          Residence  Age  Class_Time Class_Rating  \
# 0              0          Delhi-NCR   20           4         Poor
# 1              1          Delhi-NCR   20           3         Poor
# 2              2          Delhi-NCR   25           0         Poor
# 3              3          Delhi-NCR   20           2         Poor
# 4              4  Outside Delhi-NCR   20           2         Poor
# ...          ...                ...  ...         ...          ...
# 1619        1619          Delhi-NCR   25           4    Excellent
# 1620        1620          Delhi-NCR   15           4    Excellent
# 1621        1621  Outside Delhi-NCR   15           4    Excellent
# 1622        1622          Delhi-NCR   20           4    Excellent
# 1623        1623  Outside Delhi-NCR   20           0    Excellent
#
#         Class_Medium  Self_Study_Time  Fitness_Time  Sleep_Time  \
# 0     Laptop/Desktop                3             0           6
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1624 entries, 0 to 1623
# Data columns (total 21 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              1624 non-null   int64
#  1   Residence               1624 non-null   object
#  2   Age                     1624 non-null   int64
#  3   Class_Time              1624 non-null   int64
#  4   Class_Rating            1624 non-null   object
#  5   Class_Medium            1624 non-null   object
#  6   Self_Study_Time         1624 non-null   int64
#  7   Fitness_Time            1624 non-null   int64
#  8   Sleep_Time              1624 non-null   int64
#  9   Social_Media_Time       1624 non-null   int64
#  10  Social_Media_Platform   1624 non-null   object
#  11  TV_Time                 1624 non-null   int64
#  12  Meals_Number            1624 non-null   int64
#  13  Weight_Change           1624 non-null   int64
# ...

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#            Residence  Age  Class_Time Class_Rating    Class_Medium  \
# 0          Delhi-NCR   20           4         Poor  Laptop/Desktop
# 1          Delhi-NCR   20           3         Poor      Smartphone
# 2          Delhi-NCR   25           0         Poor      Smartphone
# 3          Delhi-NCR   20           2         Poor      Smartphone
# 4  Outside Delhi-NCR   20           2         Poor          Tablet
#
#    Self_Study_Time  Fitness_Time  Sleep_Time  Social_Media_Time  \
# 0                3             0           6                  2
# 1                2             1           6                  5
# 2                4             0           6                  1
# 3                2             1           6                  4
# 4                1             1           9                  5
#
#   Social_Media_Platform  TV_Time  Meals_Number  Weight_Change Health_Issue  \
# 0                Others        0             3              2           NO
# ...

# %%
df = pd.get_dummies(df, prefix="Miss", 
                            columns=["Miss"], 
                            drop_first=False)
df.head()
# Out:
#            Residence  Age  Class_Time Class_Rating    Class_Medium  \
# 0          Delhi-NCR   20           4         Poor  Laptop/Desktop
# 1          Delhi-NCR   20           3         Poor      Smartphone
# 2          Delhi-NCR   25           0         Poor      Smartphone
# 3          Delhi-NCR   20           2         Poor      Smartphone
# 4  Outside Delhi-NCR   20           2         Poor          Tablet
#
#    Self_Study_Time  Fitness_Time  Sleep_Time  Social_Media_Time  \
# 0                3             0           6                  2
# 1                2             1           6                  5
# 2                4             0           6                  1
# 3                2             1           6                  4
# 4                1             1           9                  5
#
#   Social_Media_Platform  ...  Time_Utilized  More_Social_connection  \
# 0                Others  ...             NO                     YES
# ...

# %%
df = pd.get_dummies(df, prefix="Residence", 
                            columns=["Residence"], 
                            drop_first=False)
df.head()
# Out:
#    Age  Class_Time Class_Rating    Class_Medium  Self_Study_Time  \
# 0   20           4         Poor  Laptop/Desktop                3
# 1   20           3         Poor      Smartphone                2
# 2   25           0         Poor      Smartphone                4
# 3   20           2         Poor      Smartphone                2
# 4   20           2         Poor          Tablet                1
#
#    Fitness_Time  Sleep_Time  Social_Media_Time Social_Media_Platform  TV_Time  \
# 0             0           6                  2                Others        0
# 1             1           6                  5             Instagram        0
# 2             0           6                  1               Youtube        0
# 3             1           6                  4             Instagram        0
# 4             1           9                  5             Instagram        0
#
#    ...  Total_studying_time  Total_resting_time Miss_ALL Miss_BEING OUTSIDE  \
# ...

# %%
df = pd.get_dummies(df, prefix="Medium", 
                            columns=["Class_Medium"], 
                            drop_first=False)
df.head()
# Out:
#    Age  Class_Time Class_Rating  Self_Study_Time  Fitness_Time  Sleep_Time  \
# 0   20           4         Poor                3             0           6
# 1   20           3         Poor                2             1           6
# 2   25           0         Poor                4             0           6
# 3   20           2         Poor                2             1           6
# 4   20           2         Poor                1             1           9
#
#    Social_Media_Time Social_Media_Platform  TV_Time  Meals_Number  ...  \
# 0                  2                Others        0             3  ...
# 1                  5             Instagram        0             3  ...
# 2                  1               Youtube        0             1  ...
# 3                  4             Instagram        0             3  ...
# 4                  5             Instagram        0             3  ...
#
#    Miss_NOTHING Miss_SCHOOL/WORK Miss_SOCIALIZE Miss_TRAVELLING  \
# ...

# %%
df = pd.get_dummies(df, prefix="Social_Media", 
                            columns=["Social_Media_Platform"], 
                            drop_first=False)
df.head()
# Out:
#    Age  Class_Time Class_Rating  Self_Study_Time  Fitness_Time  Sleep_Time  \
# 0   20           4         Poor                3             0           6
# 1   20           3         Poor                2             1           6
# 2   25           0         Poor                4             0           6
# 3   20           2         Poor                2             1           6
# 4   20           2         Poor                1             1           9
#
#    Social_Media_Time  TV_Time  Meals_Number  Weight_Change  ...  \
# 0                  2        0             3              2  ...
# 1                  5        0             3              1  ...
# 2                  1        0             1              1  ...
# 3                  4        0             3              0  ...
# 4                  5        0             3              0  ...
#
#   Residence_Delhi-NCR Residence_Outside Delhi-NCR Medium_Any Gadget  \
# ...

# %%
df['rating'] = np.where(df['Class_Rating']=='Poor', 0, 1)
df.drop('Class_Rating', axis=1, inplace=True)
df.head()
# Out:
#    Age  Class_Time  Self_Study_Time  Fitness_Time  Sleep_Time  \
# 0   20           4                3             0           6
# 1   20           3                2             1           6
# 2   25           0                4             0           6
# 3   20           2                2             1           6
# 4   20           2                1             1           9
#
#    Social_Media_Time  TV_Time  Meals_Number  Weight_Change Health_Issue  ...  \
# 0                  2        0             3              2           NO  ...
# 1                  5        0             3              1           NO  ...
# 2                  1        0             1              1          YES  ...
# 3                  4        0             3              0           NO  ...
# 4                  5        0             3              0          YES  ...
#
#   Residence_Outside Delhi-NCR Medium_Any Gadget Medium_Laptop/Desktop  \
# ...

# %%
df['Health_issue'] = np.where(df['Health_Issue']=='YES', 1, 0)
df.drop('Health_Issue', axis=1, inplace=True)
df.head()
# Out:
#    Age  Class_Time  Self_Study_Time  Fitness_Time  Sleep_Time  \
# 0   20           4                3             0           6
# 1   20           3                2             1           6
# 2   25           0                4             0           6
# 3   20           2                2             1           6
# 4   20           2                1             1           9
#
#    Social_Media_Time  TV_Time  Meals_Number  Weight_Change     Stress_Busters  \
# 0                  2        0             3              2              MUSIC
# 1                  5        0             3              1  ONLINE ACTIVITIES
# 2                  1        0             1              1               WORK
# 3                  4        0             3              0  ONLINE ACTIVITIES
# 4                  5        0             3              0  ONLINE ACTIVITIES
#
#    ... Medium_Any Gadget Medium_Laptop/Desktop  Medium_Smartphone  \
# ...

# %%
df = pd.get_dummies(df, prefix="Stress_Busters", 
                            columns=["Stress_Busters"], 
                            drop_first=False)
df.head()
# Out:
#    Age  Class_Time  Self_Study_Time  Fitness_Time  Sleep_Time  \
# 0   20           4                3             0           6
# 1   20           3                2             1           6
# 2   25           0                4             0           6
# 3   20           2                2             1           6
# 4   20           2                1             1           9
#
#    Social_Media_Time  TV_Time  Meals_Number  Weight_Change Time_Utilized  ...  \
# 0                  2        0             3              2            NO  ...
# 1                  5        0             3              1            NO  ...
# 2                  1        0             1              1            NO  ...
# 3                  4        0             3              0            NO  ...
# 4                  5        0             3              0            NO  ...
#
#   Stress_Busters_INDOOR ACTIVITIES  Stress_Busters_MUSIC  \
# 0                            False                  True
# ...

# %%
df['Time_utilized'] = np.where(df['Time_Utilized']=='YES', 1, 0)
df.drop('Time_Utilized', axis=1, inplace=True)
df.head()
# Out:
#    Age  Class_Time  Self_Study_Time  Fitness_Time  Sleep_Time  \
# 0   20           4                3             0           6
# 1   20           3                2             1           6
# 2   25           0                4             0           6
# 3   20           2                2             1           6
# 4   20           2                1             1           9
#
#    Social_Media_Time  TV_Time  Meals_Number  Weight_Change  \
# 0                  2        0             3              2
# 1                  5        0             3              1
# 2                  1        0             1              1
# 3                  4        0             3              0
# 4                  5        0             3              0
#
#   More_Social_connection  ...  Stress_Busters_MUSIC  \
# 0                    YES  ...                  True
# 1                     NO  ...                 False
# 2                    YES  ...                 False
# ...

# %%
df['More_social_connection'] = np.where(df['More_Social_connection']=='YES', 1, 0)
df.drop('More_Social_connection', axis=1, inplace=True)
df.head()
# Out:
#    Age  Class_Time  Self_Study_Time  Fitness_Time  Sleep_Time  \
# 0   20           4                3             0           6
# 1   20           3                2             1           6
# 2   25           0                4             0           6
# 3   20           2                2             1           6
# 4   20           2                1             1           9
#
#    Social_Media_Time  TV_Time  Meals_Number  Weight_Change  \
# 0                  2        0             3              2
# 1                  5        0             3              1
# 2                  1        0             1              1
# 3                  4        0             3              0
# 4                  5        0             3              0
#
#    Total_studying_time  ...  Stress_Busters_NO ACTIVITIES  \
# 0                    7  ...                         False
# 1                    5  ...                         False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1624 entries, 0 to 1623
# Data columns (total 43 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Age                               1624 non-null   int64
#  1   Class_Time                        1624 non-null   int64
#  2   Self_Study_Time                   1624 non-null   int64
#  3   Fitness_Time                      1624 non-null   int64
#  4   Sleep_Time                        1624 non-null   int64
#  5   Social_Media_Time                 1624 non-null   int64
#  6   TV_Time                           1624 non-null   int64
#  7   Meals_Number                      1624 non-null   int64
#  8   Weight_Change                     1624 non-null   int64
#  9   Total_studying_time               1624 non-null   int64
#  10  Total_resting_time                1624 non-null   int64
#  11  Miss_ALL                          1624 non-null   bool
# ...

# %%
# Save the file for next class
df.to_csv(r'C:\Users\dilan\Documents\Github\DataAnalysis_and_AI\period_2\Resources\Datasets\procesado2.csv', index=False)

# %%
# pip install kneed

# %%
from kneed import KneeLocator
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.preprocessing import StandardScaler

# %%
kmeans_kwargs = {
     "init": "random",
     "n_init": 10,
     "max_iter": 300,
     "random_state": 42,
 }

# A list holds the SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(df)
    sse.append(kmeans.inertia_)

# %%
import matplotlib.pyplot as plt

plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(
    range(1, 11), sse, curve="convex", direction="decreasing"
)

kl.elbow
# Out:
# 3

# %%
# A list holds the silhouette coefficients for each k
silhouette_coefficients = []

# Notice you start at 2 clusters for silhouette coefficient
for k in range(2, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(df)
    score = silhouette_score(df, kmeans.labels_)
    silhouette_coefficients.append(score)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(2, 11), silhouette_coefficients)
plt.xticks(range(2, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("Silhouette Coefficient")
plt.show()

# %% [markdown]
# ### Which value would recommend the Silohuette method?
